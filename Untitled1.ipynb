# %%
import numpy as np
from scipy.stats import gamma
import matplotlib.pyplot as plt

# %%
x_list = np.arange(0, 20, .1)
y_list = [gamma.pdf(x, a=2, scale=4) for x in x_list]

plt.plot(x_list, y_list)
