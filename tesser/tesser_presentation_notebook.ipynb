# %% [markdown]
# # Tesser Presentations on Structured Learning and Generalized Induction from Behavioral Experiments

# %%
# import modules for data extraction and running learning agents
import numpy as np
import util # functions to read behavioral data (structure learning, induction)
import sr # core model functions for learning/running experiment phases
# import fit # model fitting/parameter optimization
# import rsa # creating and testing model RDM
import plot_models

# %%
help(util), help(sr)
# Out:
# Help on module util:
#
# NAME
#     util
#
# DESCRIPTION
#     # -*- coding: utf-8 -*-
#     # functions to read behavioral data (structured learning, induction)
#
# FUNCTIONS
#     drop_nan(DATA)
#         Drops NaN values from DataFrame
#
#     get_induction_data(DFRAME)
#         iNPUT DataFrame
#         OUTPUT four variable sequences for generalized induction
#
#     get_objects(DFRAME)
#         iNPUT DataFrame
#         OUTPUT object sequence numbers for successor representation
#
#     print_keys(KEYS)
#
#     read_files(SUBJECT=0, TYPE='', PART=[1, 2], RUN=[1, 2, 3, 4, 5, 6], PATH='/home/rodrigo/Dropbox/tesser_successor/Data/')
#         simple for loop to obtain all data from .txt files in a given directory
#         Inputs:
#
#         SUBJECT: Integer representing subject # for tesser behavioral studies
#         TYPE: String describing the type of experimental data;
#         'structured' for structured learning or 'induction' for gen induction
# ...

# %%
plot_models.plot_explore_runs('track changes', 30, 0.5, 0.5)
